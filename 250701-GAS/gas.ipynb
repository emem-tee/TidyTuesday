# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------------------ --------------- 6.8/11.0 MB 32.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 32.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ----------------------- ---------------- 7.6/12.7 MB 36.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.7 MB 30.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 29.6 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
# ...

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------------- -------------- 5.2/8.1 MB 29.0 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 15.1 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 63.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------------------- ------------ 4.7/7.0 MB 28.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 28.7 MB/s eta 0:00:00
# ...
#
#    ----- ---------------------------------- 1/8 [pillow]
# ...

# %%
import pandas as pd

# %%
gas = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-07-01/weekly_gas_prices.csv')

# %%
gas.info()
gas.head(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22360 entries, 0 to 22359
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         22360 non-null  object
#  1   fuel         22360 non-null  object
#  2   grade        22360 non-null  object
#  3   formulation  19672 non-null  object
#  4   price        22360 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 873.6+ KB
#          date      fuel    grade   formulation  price
# 0  1990-08-20  gasoline  regular           all  1.191
# 1  1990-08-20  gasoline  regular  conventional  1.191
# 2  1990-08-27  gasoline  regular           all  1.245
# 3  1990-08-27  gasoline  regular  conventional  1.245

# %%
gas.index = pd.to_datetime(gas['date'])

# %%
gas.drop('date', axis = 1, inplace = True)

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22360 entries, 1990-08-20 to 2025-06-23
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fuel         22360 non-null  object
#  1   grade        22360 non-null  object
#  2   formulation  19672 non-null  object
#  3   price        22360 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.4+ MB

# %%
for i in gas:
    print(type(i))
    break
# Out:
# <class 'str'>

# %%
[gas[col_].value_counts() for col_ in gas if gas[col_].dtypes == 'object']
# Out:
# [fuel
#  gasoline    19672
#  diesel       2688
#  Name: count, dtype: int64,
#  grade
#  all                 6506
#  regular             5222
#  midgrade            4788
#  premium             4788
#  ultra_low_sulfur     960
#  low_sulfur            96
#  Name: count, dtype: int64,
#  formulation
#  all             6687
#  conventional    6601
#  reformulated    6384
#  Name: count, dtype: int64]

# %%
gas.select_dtypes(include=['object']).apply(lambda x: x.value_counts())
# Out:
#                      fuel   grade  formulation
# all                   NaN  6506.0       6687.0
# conventional          NaN     NaN       6601.0
# diesel             2688.0     NaN          NaN
# gasoline          19672.0     NaN          NaN
# low_sulfur            NaN    96.0          NaN
# midgrade              NaN  4788.0          NaN
# premium               NaN  4788.0          NaN
# reformulated          NaN     NaN       6384.0
# regular               NaN  5222.0          NaN
# ultra_low_sulfur      NaN   960.0          NaN

# %%
for i in gas[]
